# %%
from ipywebrtc import CameraStream, ImageRecorder

# %%
camera = CameraStream(constraints=
                      {'facing_mode': 'user',
                       'audio': False,
                       'video': { 'width': 640, 'height': 480 }
                       })

# %%
camera
# Out:
# CameraStream(constraints={'facing_mode': 'user', 'audio': False, 'video': {'width': 640, 'height': 480}})

# %%
camera=None

# %%
import cv2
image = cv2.imread('../data/originals/2_original_2.png')

w,h,l = image.shape
k=10

# %%
import numpy as np
image = np.random_noise(image)
# image = cv2.medianBlur(image,2,  cv2.BORDER_DEFAULT)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-150-9b7cf64493fb> in <module>
#       1 import numpy as np
# ----> 2 image = np.random_noise(image)
#       3 # image = cv2.medianBlur(image,2,  cv2.BORDER_DEFAULT)
#
# AttributeError: module 'numpy' has no attribute 'random_noise'

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.imshow(image);
